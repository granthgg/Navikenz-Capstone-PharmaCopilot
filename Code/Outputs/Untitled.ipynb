# %%
# !pip install pandas pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# Replace with the path to your parquet file
file_path = 'processed_timeseries.parquet'

# Load the parquet file
df = pd.read_parquet(file_path)

# Display the dataframe
df.head(50)  # Shows the first 5 rows
# Out:
#     file_id           timestamp  index  campaign  batch  code  tbl_speed  \
# 0         1 2018-11-22 23:07:00    1.5       4.0   26.0   1.0   0.000000
# 1         1 2018-11-22 23:08:00    6.5       4.0   26.0   1.0   0.000000
# 2         1 2018-11-22 23:09:00   12.5       4.0   26.0   1.0   0.000000
# 3         1 2018-11-22 23:10:00   18.5       4.0   26.0   1.0   0.000000
# 4         1 2018-11-22 23:11:00   24.5       4.0   26.0   1.0   0.000000
# 5         1 2018-11-22 23:12:00   30.5       4.0   26.0   1.0   0.000000
# 6         1 2018-11-22 23:13:00   36.5       4.0   26.0   1.0   0.000000
# 7         1 2018-11-22 23:14:00   42.5       4.0   26.0   1.0   0.000000
# 8         1 2018-11-22 23:15:00   48.5       4.0   26.0   1.0   0.000000
# 9         1 2018-11-22 23:16:00   54.5       4.0   26.0   1.0   0.000000
# 10        1 2018-11-22 23:17:00   60.5       4.0   26.0   1.0   0.000000
# 11        1 2018-11-22 23:18:00   66.5       4.0   26.0   1.0  60.283333
# ...

# %%
df.isnull().sum()
# Out:
# file_id            0
# timestamp          0
# index        7587276
# campaign     7587276
# batch        7587276
# code         7587276
# tbl_speed    7587434
# fom          7587434
# main_comp    7587434
# tbl_fill     7587439
# SREL         7587434
# pre_comp     7587434
# produced     7587483
# waste        7587434
# cyl_main     7587458
# cyl_pre      7587483
# stiffness    7587434
# ejection     7587441
# dtype: int64

# %%
df.shape
# Out:
# (7873762, 18)

# %%
df.describe()
# Out:
#             file_id                      timestamp         index  \
# count  7.873762e+06                        7873762  2.864860e+05
# mean   1.259520e+01  2019-05-22 18:23:51.260846336  1.809464e+06
# min    1.000000e+00            1900-01-01 00:00:00  1.500000e+00
# 25%    7.000000e+00            2019-03-01 05:13:00  4.289780e+05
# 50%    1.100000e+01            2019-05-17 15:37:00  8.582795e+05
# 75%    2.100000e+01            2019-08-06 01:25:00  3.596043e+06
# max    2.500000e+01            2020-08-06 12:47:00  4.720207e+06
# std    7.581479e+00                            NaN  1.548202e+06
#
#             campaign          batch           code      tbl_speed  \
# count  286486.000000  286486.000000  286486.000000  286328.000000
# mean       61.054227     262.953111      12.732252      75.113657
# min         3.000000       1.000000       1.000000       0.000000
# 25%        34.000000     123.000000       6.000000       0.000000
# ...
